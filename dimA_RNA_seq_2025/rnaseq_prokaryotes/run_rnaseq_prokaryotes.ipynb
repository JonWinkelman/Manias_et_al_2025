# %%
import os
import pandas as pd

# %%
if not os.path.exists('./jw_utils'):
    # !git clone https://github.com/JonWinkelman/jw_utils.git
from jw_utils import parse_gff as pgf

# %% [markdown]
# ### Get appropriate files and fill in paths
# **Files needed:**
#     1. raw compressed fastq files (.fastq.gz)
#     3. GTF or GFF annotation file
#     4. Genomic sequence in fasta format
#     5.  samplesheet.csv
#
# **Paths to fill in:**
#     1. path to AWS project dir
#     2. genome filename
#     3. gff or gtf filename
#
# **Structure of AWS project dir**
# Folders:
# 1. raw/
#      - fastq files
# 2. references/
#      - annotation files
#      - genome sequence
# 3. assets/
#      - samplesheet.csv
# 4. results/

# %% [markdown]
# ## Fill in these paths!!
# **This assumes that the AWS 'assets' and 'references' directories have been populated
# with the references/<genome>.fasta, references/<annotation>.gff and assets/samplesheet.csv**

# %%
aws_project_dir = "s3://mukherjee-lab/dimA_RNA_seq_2025/"
genome_filename = 'GCA_000014625.1_ASM1462v1_genomic.fna'
annotation_filename = 'genomic.gff'

# %% [markdown]
# #### Create aws file paths:

# %%
annotation_fp = os.path.join(aws_project_dir, 'references/', annotation_filename)
genome_fp = os.path.join(aws_project_dir, 'references/', genome_filename)
samplesheet_fp = os.path.join(aws_project_dir,'assets/samplesheet.csv')

work = os.path.join(aws_project_dir,'work/')
outdir = os.path.join(aws_project_dir,'results/')

# %% [markdown]
# #### create local fps and files for testing.

# %%
references = './references'
assets = './assets'
test_dir = 'fq_subsample'
if not os.path.exists(references):
    os.mkdir(references)
if not os.path.exists(assets):
    os.mkdir(assets)
if not os.path.exists(test_dir):
    os.mkdir(test_dir)

# %% [markdown]
# ## Test pipeline locally on small subsampled fastq files

# %% [markdown]
# #### Run test of pipeline on small subsampled dataset.
# cell 1: download 4 fastq files to local fq_subsample dir.
# cell 2: subsample those 4 files

# %% [markdown]
# ### run on AWS batch

# %% [raw]
# ### make sure you have a profile for running aws batch in nextflow.config file
# jonathan {
#         process.executor = 'awsbatch'
#         process.queue = 'general-rnaseq'
#         aws.region = 'us-east-2'
#         aws.batch.cliPath = '/home/ec2-user/miniconda/bin/aws'
# 		docker.enabled         = true
# 		docker.userEmulation   = true
# 		singularity.enabled    = false
# 		podman.enabled         = false
# 		shifter.enabled        = false
# 	    charliecloud.enabled   = false
#         docker.registry        = 'quay.io'
#     }

# %%
work = os.path.join(aws_project_dir,'work/')
# genome_fp = os.path.join(aws_project_dir, 'references/', genome_filename)
outdir = os.path.join(aws_project_dir,'results')
# input = os.path.join(aws_project_dir,'assets/samplesheet.csv')
# gff = os.path.join(aws_project_dir,'references/sequence.gff3')

# %%
annotation_fp
# Out:
# 's3://mukherjee-lab/dimA_RNA_seq_2025/references/genomic.gff'

# %%
# !nextflow run main.nf -profile jonathan --input $samplesheet_fp --fasta $genome_fp --outdir $outdir --gff $annotation_fp -work-dir $work -resume
# Out:
# Nextflow 24.10.4 is available - Please consider updating your version to it
# N E X T F L O W  ~  version 23.10.1
# Launching `main.nf` [boring_lagrange] DSL2 - revision: 174702b01e
# WARN: The following invalid input values have been detected:
#
# * --gff: s3://mukherjee-lab/dimA_RNA_seq_2025/references/genomic.gff
#
#
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/prokrnaseq v1.0dev
# ------------------------------------------------------
# Core Nextflow options
#   runName        : boring_lagrange
#   containerEngine: docker
#   launchDir      : /Users/jonathanwinkelman/Trestle_long-term-storage/Mukherjee_lab/dima_RNA_seq_2025/rnaseq_prokaryotes
#   workDir        : /mukherjee-lab/dimA_RNA_seq_2025/work
#   projectDir     : /Users/jonathanwinkelman/Trestle_long-term-storage/Mukherjee_lab/dima_RNA_seq_2025/rnaseq_prokaryotes
#   userName       : jonathanwinkelman
#   profile        : jonathan
#   configFiles    :
#
# Input/output options
#   input          : s3://mukherjee-lab/dimA_RNA_seq_2025/assets/samplesheet.csv
#   outdir         : s3://mukherjee-lab/dimA_RNA_seq_2025/results
#
# Reference genome options
#   fasta          : s3://mukherjee-lab/dimA_RNA_seq_2025/references/GCA_000014625.1_ASM1462v1_genomic.fna
#
# Max job request options
#   max_cpus       : 12
#   max_memory     : 16.GB
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/prokrnaseq for your analysis please cite:
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/prokrnaseq/blob/master/CITATIONS.md
#
# Uploading local `bin` scripts folder to s3://mukherjee-lab/dimA_RNA_seq_2025/work/tmp/15/27258fa4314bfee186a08834e28c2b/bin
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
#
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
#
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (3)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 4
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (6)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 7
# [3e/fc191d] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 7
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (15)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [a0/bb5219] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 9
# [5c/7b65bb] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 10
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (21)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [24/2a4d41] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 13
# [c9/02f2ad] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 13
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (27)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [c1/84e2b0] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [2b/d6b25f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [2a/2034a6] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [2a/2034a6] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (33)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [60/203933] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (34)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [60/203933] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [d9/580733] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (34)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [60/203933] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [d9/580733] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (34)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [60/203933] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [d9/580733] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 1
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (34)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [d9/580733] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b5/08ad44] process > NFCORE_PROKRNASEQ:PROKRNASE... [  6%] 1 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [c1/84e2b0] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [e1/41f3b5] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [85/4d7f01] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 26%] 4 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [24/2a4d41] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 33%] 5 of 15
# [90/7ddd84] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 13%] 2 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [24/2a4d41] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 33%] 5 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 2
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (35)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [24/2a4d41] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 33%] 5 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [b4/2efb17] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [24/2a4d41] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 33%] 5 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [c8/e396f2] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 40%] 6 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [e8/07afe5] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 46%] 7 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [6c/bf26ce] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 53%] 8 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [5d/53b198] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 60%] 9 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [a0/bb5219] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 66%] 10 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [f2/0466ce] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 73%] 11 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [4f/08ccac] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 80%] 12 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [2a/2034a6] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 86%] 13 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [0d/1b6ef3] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 93%] 14 of 15
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [fa/25ab4a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 15 of 15 ✔
# [8e/a3c43f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 20%] 3 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 3
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (36)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [fa/25ab4a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 15 of 15 ✔
# [81/770c4f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 26%] 4 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [7b/eb2a69] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 4
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (37)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [fa/25ab4a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 15 of 15 ✔
# [81/770c4f] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 26%] 4 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [c3/42764b] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 4
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (37)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [fa/25ab4a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 15 of 15 ✔
# [38/0a94c5] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 33%] 5 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [c3/42764b] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 5
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch (38)
# [1b/c45876] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [fa/25ab4a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 15 of 15 ✔
# [38/0a94c5] process > NFCORE_PROKRNASEQ:PROKRNASE... [ 33%] 5 of 15
# [58/e40d56] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [48/b783be] process > NFCORE_PROKRNASEQ:PROKRNASE... [  0%] 0 of 5
# [f0/6ac87a] process > NFCORE_PROKRNASEQ:PROKRNASE... [100%] 1 of 1 ✔
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
# [-        ] process > NFCORE_PROKRNASEQ:PROKRNASE... -
#
# executor >  awsbatch